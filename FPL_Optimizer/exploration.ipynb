# %% [markdown]
# # FPL Data Exploration & Model Training
#
# This notebook demonstrates how to fetch historical data, engineer features, and train an XGBoost model for FPL point prediction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ml_engine import FPLEngine

# %matplotlib inline

# %% [markdown]
# ## 1. Fetch Historical Data

# %%
engine = FPLEngine()
historical_data = engine.fetch_historical_data(seasons=['2021-22', '2022-23', '2023-24'])

# %% [markdown]
# ## 2. Prepare Training Data (Feature Engineering)

# %%
full_df = engine.prepare_training_data(historical_data)
print(f"Training data shape: {full_df.shape}")
full_df.head()

# %% [markdown]
# ## 3. Train XGBoost Model

# %%
model, features = engine.train_model(full_df)
print(f"Trained with features: {features}")

# %% [markdown]
# ## 4. Feature Importance

# %%
xgb.plot_importance(model)
plt.show()

# %% [markdown]
# ## 5. Save to Azure

# %%
# engine.save_model_to_azure(model, features)
